# %% [markdown]
# # MONKEY POX KAGGLE DATASET

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score,precision_score,confusion_matrix,classification_report,recall_score

# %%
# importing the dataset
dataset=pd.read_csv(r"C:\Users\Muhmmad shaban\Downloads\MonkeyPox.csv")

# %%
dataset.head(3)
# Out:
#    Systemic Illness  Rectal Pain  Sore Throat  Penile Oedema  Oral Lesions  \
# 0                 1            0            1              1             1
# 1                 2            1            0              1             1
# 2                 2            0            1              1             0
#
#    Solitary Lesion  Swollen Tonsils  HIV Infection  \
# 0                0                1              0
# 1                0                0              1
# 2                0                0              1
#
#    Sexually Transmitted Infection  MonkeyPox
# 0                               0          0
# 1                               0          1
# 2                               0          1

# %%
# examing the shape of the dataset
dataset.shape
# Out:
# (25000, 10)

# %%
# corelation heatmapp of the dataset
sns.heatmap(dataset.corr())
# Out:
# <Axes: >

# %%
# examing the value count 
dataset["MonkeyPox"].value_counts()
# Out:
# MonkeyPox
# 1    15909
# 0     9091
# Name: count, dtype: int64

# %%
# spliting the dataset into the input and output for the models
x=dataset.iloc[:,:-1]
y=dataset["MonkeyPox"]

# %%
# using standard scaller to scale the dataset
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
x=pd.DataFrame(ss.fit_transform(x),columns=x.columns)

# %%
# using Random Foresst classifier for the model 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# spiling the dataset into the training and the testing parts
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
#fiting the train data
rf=RandomForestClassifier(max_depth=8,random_state=42,n_estimators=100)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=8, random_state=42)

# %%
print("THE TESTING ACCURACY IS ",rf.score(x_test,y_test)*100)

print("THE TRAINING ACCURACY IS",rf1.score(x_train,y_train)*100)
# Out:
# THE TESTING ACCURACY IS  70.42
# THE TRAINING ACCURACY IS 60.27

# %%
# here printing the classification report for the model
pr=rf.predict(x_test)
print(classification_report(y_test,pr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.38      0.50      1754
#            1       0.73      0.92      0.82      3246
#
#     accuracy                           0.73      5000
#    macro avg       0.73      0.65      0.66      5000
# weighted avg       0.73      0.73      0.70      5000

# %% [markdown]
# ## SUCCESSFULLY ACIEVE THE ACCURACY OF THE 70.42

# %% [markdown]
# # THE END OF THE PROJECT
